# %%
import cbpro

# %%
public_client = cbpro.PublicClient()
public_client

# %%
cryptocurrencies = public_client.get_currencies()

# %%
for cc in cryptocurrencies:
    print(cc['details'])
    print('=========================================')
# Out:
# {'type': 'crypto', 'symbol': None, 'network_confirmations': 14, 'sort_order': 205, 'crypto_address_link': 'https://etherscan.io/token/0x7f08962d948c5c59cac284035748be21134ebc2b?a={{address}}', 'crypto_transaction_link': None, 'push_payment_methods': ['crypto'], 'group_types': [], 'display_name': None, 'processing_time_seconds': None, 'min_withdrawal_amount': 0.07, 'max_withdrawal_amount': 424200}
# ...
# {'type': 'crypto', 'symbol': None, 'network_confirmations': 14, 'sort_order': 944, 'crypto_address_link': 'https://etherscan.io/token/0x3d658390460295fb963f54dc0899cfb1c30776df?a={{address}}', 'crypto_transaction_link': 'https://etherscan.io/tx/0x{{txId}}', 'push_payment_methods': ['crypto'], 'group_types': [], 'display_name': None, 'processing_time_seconds': None, 'min_withdrawal_amount': 1e-08, 'max_withdrawal_amount': 18103500}
# ...

# %%
public_client.get_product_24hr_stats('ETH-USD')
# Out:
# {'open': '1685.12',
#  'high': '1855',
#  'low': '1656',
#  'last': '1840.66',
#  'volume': '425999.39717187',
#  'volume_30day': '9589704.3771373'}

# %%
public_client.get_product_historic_rates('ETH-USD')
# Out:
# [[1660144800, 1842.5, 1846.42, 1842.91, 1844.95, 405.29645979],
#  [1660144740, 1839.93, 1843, 1840, 1842.9, 352.94952772],
#  [1660144680, 1837.8, 1842.65, 1842.34, 1839.99, 319.57692315],
#  [1660144620, 1840.94, 1843.64, 1841.75, 1842.12, 294.59677532],
#  [1660144560, 1838.89, 1842.27, 1842.11, 1841.2, 412.76895112],
#  [1660144500, 1840.37, 1843.02, 1841.9, 1842.26, 203.10973007],
#  [1660144440, 1839.86, 1842.95, 1840.09, 1841.83, 227.72155817],
#  [1660144380, 1837.52, 1841.41, 1838.48, 1840.19, 281.36982851],
#  [1660144320, 1836.3, 1841.35, 1839.45, 1838.81, 657.76898278],
#  [1660144260, 1838.51, 1842.48, 1841.33, 1839.56, 281.22357837],
#  [1660144200, 1839.96, 1844.04, 1843.21, 1841.3, 355.18708586],
#  [1660144140, 1842.49, 1844.28, 1844.14, 1843.18, 183.6203519],
#  [1660144080, 1842.76, 1845.49, 1842.76, 1844.15, 428.86805973],
#  [1660144020, 1841.74, 1846.91, 1845.71, 1842.8, 442.41452214],
#  [1660143960, 1845.58, 1851.21, 1849.3, 1845.72, 1184.4566041],
# ...

# %%
public_client.get_products()
# Out:
# [{'id': 'REP-USD',
#   'base_currency': 'REP',
#   'quote_currency': 'USD',
#   'quote_increment': '0.01',
#   'base_increment': '0.000001',
#   'display_name': 'REP/USD',
#   'min_market_funds': '1',
#   'margin_enabled': False,
#   'post_only': False,
#   'limit_only': False,
#   'cancel_only': False,
#   'status': 'online',
#   'status_message': '',
#   'trading_disabled': False,
#   'fx_stablecoin': False,
#   'max_slippage_percentage': '0.03000000',
#   'auction_mode': False},
#  {'id': 'OXT-USD',
#   'base_currency': 'OXT',
#   'quote_currency': 'USD',
#   'quote_increment': '0.0001',
#   'base_increment': '1',
#   'display_name': 'OXT/USD',
#   'min_market_funds': '1',
#   'margin_enabled': False,
#   'post_only': False,
#   'limit_only': False,
#   'cancel_only': False,
#   'status': 'online',
#   'status_message': '',
#   'trading_disabled': False,
#   'fx_stablecoin': False,
#   'max_slippage_percentage': '0.03000000',
#   'auction_mode': False},
#  {'id': 'CHZ-USD',
# ...

# %%
public_client.get_product_ticker('ETH-USD')
# Out:
# {'ask': '1845.17',
#  'bid': '1844.98',
#  'volume': '427527.26107482',
#  'trade_id': 332138982,
#  'price': '1845.16',
#  'size': '0.00159211',
#  'time': '2022-08-10T15:25:18.433441Z'}

# %%
public_client.get_product_order_book('ETH-USD',level=1)
# Out:
# {'bids': [['1845.11', '0.25', 1]],
#  'asks': [['1845.39', '0.00842284', 1]],
#  'sequence': 33752000423,
#  'auction_mode': False,
#  'auction': None}

# %%
public_client.get_time()
# Out:
# {'iso': '2022-08-10T15:27:37.005Z', 'epoch': 1660145257.005}

# %%
keys = open('mykeys.txt','r').read().splitlines()

# %%
public = keys[0]
secret = keys[1]
passphrase = keys[2]

# %%
auth_client = cbpro.AuthenticatedClient(public,secret,passphrase)

# %%
auth_client

# %%
auth_client.buy(price="1",size ="1000",order_type="limit",product_id="ETH-EUR")
# Out:
# {'message': 'Insufficient funds'}

# %%
auth_client.buy(size ="1000",order_type="market",product_id="ETH-EUR")
# Out:
# {'message': 'Insufficient funds'}

# %%
amount_buy = 1
amount_sell = 2
while True:
    price = float(auth_client.get_product_ticker(product_id="ETH-EUR")['price'])
    if price < buy_price:
        auth_client.buy(price=amount_buy,order_type="market",product_id="ETH-EUR")
    elif price > sell_price:
        auth_client.sell(price=amount_sell,order_type="market",product_id="ETH-EUR")
    elseif:
        print("ill just wait !")
# Out:
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# 1772.84
# ...
